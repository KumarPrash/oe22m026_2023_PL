# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import geopandas as gpd
import urllib
import shutil
# %matplotlib inline

# %%
pip install geopandas matplotlib plotly pandas
# Out:
# Requirement already satisfied: geopandas in c:\users\prash\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: matplotlib in c:\users\prash\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: plotly in c:\users\prash\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: pandas in c:\users\prash\appdata\roaming\python\python310\site-packages (1.5.1)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\prash\anaconda3\lib\site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in c:\users\prash\anaconda3\lib\site-packages (from geopandas) (22.0)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\prash\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\prash\anaconda3\lib\site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prash\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\prash\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prash\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\prash\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\prash\appdata\roaming\python\python310\site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\prash\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prash\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prash\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\prash\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prash\appdata\roaming\python\python310\site-packages (from pandas) (2022.5)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\prash\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: certifi in c:\users\prash\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2022.12.7)
# Requirement already satisfied: click~=8.0 in c:\users\prash\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\prash\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\prash\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\prash\appdata\roaming\python\python310\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\prash\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (65.6.3)
# Requirement already satisfied: colorama in c:\users\prash\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
type(world)
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_7612\117303094.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# geopandas.geodataframe.GeoDataFrame

# %%
# Load the 'naturalearth_lowres' dataset from GeoPandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Load the COVID-19 data (replace with your actual COVID-19 dataset)
covid_data = pd.read_csv('covid_data.csv')

# Merge the COVID-19 data with the GeoPandas dataset based on country names
merged_data = world.set_index('name').join(covid_data.set_index('Country/Region'))

# Plot the chloropleth map
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
merged_data.plot(column='Confirmed', cmap='coolwarm', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)
ax.set_title('COVID-19 Cases Worldwide')
plt.axis('off')

# Save the chloropleth map as a PNG file
plt.savefig('covid_choropleth.png')

# Show the map
plt.show()
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_7612\960225499.py:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
print(covid_data)
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 0              0       0          0       0  Eastern Mediterranean
# 1              0       0          0       0                 Europe
# 2              0       0          0       0                 Africa
# 3              0       0          0       0                 Europe
# 4              0       0          0       0                 Africa
# ...          ...     ...        ...     ...                    ...
# 49063        865      14        734     117                 Africa
# 49064       1691     483        833     375  Eastern Mediterranean
# 49065        354       7        328      19                 Africa
# 49066       7235      60       6028    1147                 Europe
# 49067        505      12        128     365                 Africa
#
# [49068 rows x 10 columns]
